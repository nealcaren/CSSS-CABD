# %% [markdown]
# We aren't all happy at the same time
#
# ![](https://raw.github.com/nealcaren/workshop_2014/master/notebooks/images/twitter_day.png)
#
# A list based sentiment analysis by Scott Golder and Michael Macy

# %% [markdown]
# Winning makes us happy.
# ![](https://raw.github.com/nealcaren/workshop_2014/master/notebooks/images/fb.png)
# by Sean J. Taylor (@seanjtaylor)

# %% [markdown]
# ![](https://raw.github.com/nealcaren/workshop_2014/master/notebooks/images/blank.png)

# %% [markdown]
# #### Start up a blank notebook
#
# You can copy and paste from this one, but typing yourself is learning.

# %% [markdown]
# #### Data types
#
# Strings

# %%
tweet = 'We have some delightful new food in the cafeteria. Awesome!!!'

# %% [markdown]
# Open a note book and copy this text over.
#
# Then press `shift-enter` or select  `Cell-Run` from the pull down menu to `run` it.

# %% [markdown]
# What's in there?
#
# In a new cell, type `tweet` and then run the cell

# %%
tweet
# Out:
# 'We have some delightful new food in the cafeteria. Awesome!!!'

# %% [markdown]
# We can also `print` out the contents.

# %%
print(tweet)
# Out:
# We have some delightful new food in the cafeteria. Awesome!!!

# %% [markdown]
# Python doesn't care if you use `'`, `"`, or even `'''` for your strings.

# %%
tweet = "We have some delightful new food in the cafeteria. Awesome!!!"
print(tweet)
# Out:
# We have some delightful new food in the cafeteria. Awesome!!!

# %% [markdown]
# Will this work?
#
# `tweet = "Does anyone call Oslo "O-Town"?"`
#
# Guess? Try it!

# %%
tweet = "Does anyone call Oslo "O-Town"?"
# Out:
#   File "<ipython-input-4-e87405e6d3c7>", line 1
#     tweet = "Does anyone call Oslo "O-Town"?"
#                                     ^
# SyntaxError: invalid syntax

# %%
tweet = '''tweet = Does anyone call Oslo "O-Town"?'''

print(tweet)
# Out:
# tweet = Does anyone call Oslo "O-Town"?

# %%
tweet = 'tweet = Does anyone call Oslo "O-Town"?'

print(tweet)
# Out:
# tweet = Does anyone call Oslo "O-Town"?

# %% [markdown]
# ### Lists - another way to store data

# %%
['everything','in','brackets','separated','by','commas.']
# Out:
# ['everything', 'in', 'brackets', 'separated', 'by', 'commas.']

# %% [markdown]
# One way to think about a list is as a traditional social science variable.

# %%
positive_words = ['awesome', 'good', 'nice', 'super', 'fun']

# %%
print(positive_words)
# Out:
# ['awesome', 'good', 'nice', 'super', 'fun']

# %% [markdown]
# Your turn.
#
# Make a list callled `negative_words` that includes `awful, lame, horrible` and `bad.` `print` out the contents.

# %%
negative_words = ['awful','lame','horrible','bad']
print negative_words
# Out:
# ['awful', 'lame', 'horrible', 'bad']

# %% [markdown]
# We can add things to the list with `append`.

# %%
positive_words.append('delightful')

# %%
print(positive_words)
# Out:
# ['awesome', 'good', 'nice', 'super', 'fun', 'delightful', 'delightful', 'delightful']

# %% [markdown]
# Note that we didn't write `postive_words = positive_words.append('delightful')`.
#
# `.append()` modifies the content of the list.

# %%
positive_words.append(like)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-d07de71c07d9> in <module>()
# ----> 1 positive_words.append(like)
#
# NameError: name 'like' is not defined

# %%
new_word_to_add = 'like'
positive_words.append(new_word_to_add)

# %%
print positive_words
# Out:
# ['awesome', 'good', 'nice', 'super', 'fun', 'delightful', 'like']

# %% [markdown]
# Add a bad word to your negative list and print it out.

# %% [markdown]
# Combining lists

# %%
emotional_words = negative_words + positive_words
print emotional_words
# Out:
# ['awful', 'lame', 'horrible', 'bad', 'awesome', 'good', 'nice', 'super', 'fun', 'delightful', 'like']

# %% [markdown]
# Strings can be split to create lists. I do this a lot.

# %%
tweet = 'We have some delightful new food in the cafeteria. Awesome!!!'

words = tweet.split()
print(words)
# Out:
# ['We', 'have', 'some', 'delightful', 'new', 'food', 'in', 'the', 'cafeteria.', 'Awesome!!!']

# %%
tweet = 'We have some delightful new food in the cafeteria. Awesome!!!'
print(tweet.split('.'))
# Out:
# ['We have some delightful new food in the cafeteria', ' Awesome!!!']

# %% [markdown]
# Unlike `.append()`, `.split()` doesn't alter the string strings. Strings are immutable.

# %%
tweet = 'We have some delightful new food in the cafeteria. Awesome!!!'
print(tweet.split())
print(tweet)
# Out:
# ['We', 'have', 'some', 'delightful', 'new', 'food', 'in', 'the', 'cafeteria.', 'Awesome!!!']
# We have some delightful new food in the cafeteria. Awesome!!!

# %% [markdown]
# So when you modify a string, make sure you store the results somewhere.

# %%
tweet = 'We have some delightful new food in the cafeteria. Awesome!!!'
words = tweet.split()
print(words)
# Out:
# ['We', 'have', 'some', 'delightful', 'new', 'food', 'in', 'the', 'cafeteria.', 'Awesome!!!']

# %% [markdown]
# #### Most of the fun math is in `numpy` but we can count the length of objects.

# %%
length = len(words)

length
# Out:
# 10

# %% [markdown]
# How long is tweet?

# %%
print(tweet)
len(tweet)
# Out:
# We have some delightful new food in the cafeteria. Awesome!!!
# 61

# %% [markdown]
# With functions like `len()`, Python counts the number of items in list and the number of characters in a string.

# %% [markdown]
# There's a couple of more data types that you might need:

# %%
#tuple
row = (1,3,'fish')

print row
# Out:
# (1, 3, 'fish')

# %%
#sets
set([3,4,5,5])
# Out:
# {3, 4, 5}

# %%
#Dictionary

article_1 = {'title': 'Cat in the Hat', 
             'author': 'Dr. Seuss', 
             'Year': 1957}

# %%
#And a list of dictionaries is awfully close to a JSON.
article_2 = {'title': 'Go Do Go!', 
             'author': 'PD Eastman', 
             'Year': 1961}

articles = [article_1, article_2]

articles
# Out:
# [{'Year': 1957, 'author': 'Dr. Seuss', 'title': 'Cat in the Hat'},
#  {'Year': 1961, 'author': 'PD Eastman', 'title': 'Go Do Go!'}]

# %% [markdown]
# Loops
# ---
# Was any of our sentence words in the postive word list?

# %%
for word in words:
    print word
# Out:
# We
# have
# some
# delightful
# new
# food
# in
# the
# cafeteria.
# Awesome!!!

# %%
tweet = 'We have some delightful new food in the cafeteria. Awesome!!!'
words = tweet.split()

for word in words:
    print word
# Out:
# We
# have
# some
# delightful
# new
# food
# in
# the
# cafeteria.
# Awesome!!!

# %% [markdown]
# Note the colon at the end of the first line. Python will expect the next line to be indented.

# %% [markdown]
# Print out each of the words in your emotions list.

# %% [markdown]
# We can also add conditionals, like `if` and `else` or `elif`.

# %%
for word in words:
    if word in positive_words:
        print word
# Out:
# delightful

# %% [markdown]
# Your turn. Take the following tweet and print out a plus sign for each positive word:
#
# `tweet_2 = "Food is lame today. I don't like it at all."`
#
# Don't peak.

# %%
tweet_2 = "Food is lame today. I don't like it at all."

words = tw
for word in
# Out:
#   File "<ipython-input-41-d27b20fed540>", line 4
#     for word in
#                 ^
# SyntaxError: invalid syntax

# %%
tweet_2 = "Food is lame today. I don't like it at all."
words_2 = tweet_2.split()

for word in words_2:
    if word in positive_words:
        print '+'

# %%
tweet_2 = "Food is lame today. I don't like it at all."
tweet_2 = tweet_2.replace("n't"," not")
tweet_2 = tweet_2.replace("not "," not_")

print tweet_2

words_2 = tweet_2.split()

for word in words_2:
    if word in positive_words:
        print '+'
    if word in negative_words:
        print '-'
# Out:
# Food is lame today. I do  not_like it at all.
# -

# %% [markdown]
# Like lists, we can combine strings with a `+`.

# %%
print('Python ' + 'is named after Monty Python.')
# Out:
# Python is named after Monty Python.

# %%
for word in words:
    if word in positive_words:
        print word + ' is a positive word.'
# Out:
# delightful is a positive word.

# %% [markdown]
# Will this work?
#
# `print 3 + ' is a number.'`

# %%
print 3 + ' is a number.'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-43490b2e84f2> in <module>()
# ----> 1 print 3 + ' is a number.'
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
print ['puppies','dogs'] + 'are pets.'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-47-4c744f2d275f> in <module>()
# ----> 1 print ['puppies','dogs'] + 'are pets.'
#
# TypeError: can only concatenate list (not "str") to list

# %%
print '3' + ' is a number.'

print str(3) + ' is a number.'

print '%s is a number.' % 3
# Out:
# 3 is a number.
# 3 is a number.
# 3 is a number.

# %%
for some_number in [1,2,4,9]:
    sentence = str(some_number) + ' is a number.'
    print sentence
# Out:
# 1 is a number.
# 2 is a number.
# 4 is a number.
# 9 is a number.

# %% [markdown]
# ### Text cleaning
#
# Or why Awesome!!! wasn't a positive word

# %%
print tweet.lower()
# Out:
# we have some delightful new food in the cafeteria. awesome!!!

# %% [markdown]
# But we can't do it with a list of things.

# %%
print words.lower()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-53-14fb7edbf297> in <module>()
# ----> 1 print words.lower()
#
# AttributeError: 'list' object has no attribute 'lower'

# %% [markdown]
# So you'll either need clean the whole sentence, each word, or both.

# %%
for word in words:
    word_lower = word.lower()
    if word_lower in positive_words:
        print word_lower + ' is a positive word.'
# Out:
# delightful is a positive word.

# %% [markdown]
# Updating our loop, we still don’t find `awesome!!!` yet.
#
# Why?

# %%
print 'awesome!!!'.strip('!')
# Out:
# awesome

# %% [markdown]
# Getting rid of `'!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'`

# %%
from string import punctuation

# %%
punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
'awesome!!!!'.strip(punctuation)
# Out:
# 'awesome'

# %%
'awesome?!?!'.strip(punctuation)
# Out:
# 'awesome'

# %%
word = 'awesome!!!'
word_processed = word.strip('!').lower()
print word_processed
# Out:
# awesome

# %%
for word in words:
    word_processed = word.lower()
    word_processed = word_processed.strip(punctuation)
    if word_processed in positive_words:
        print word + ' is a positive word'
# Out:
# delightful is a positive word
# Awesome!!! is a positive word

# %% [markdown]
# It worked!!!

# %% [markdown]
# But what we really care about is the count of words.

# %%
postive_counter = 0

for word in words:
    word_processed = word.lower()
    word_processed = word_processed.strip(punctuation)
    if word_processed in positive_words:
        postive_counter = postive_counter + 1
print postive_counter
# Out:
# 2

# %% [markdown]
# Let's do this for real.
#
# - Get a real list of affect words.
# - Get a real list of tweets.
# - Output the results to a csv file for additional analysis.

# %% [markdown]
# LIWC is what all the cool kids use, but there list is copyrighted. So we'll use lists of positive and negative words from:
#
# Theresa Wilson, Janyce Wiebe and Paul Hoffmann (2005). "Recognizing Contextual
# Polarity in Phrase-Level Sentiment Analysis." Proceedings of HLT/EMNLP 2005,
# Vancouver, Canada.

# %%
file_name = r'files/negative.txt'

with open(file_name, 'r') as infile:
    negative_file = infile.read()

# %% [markdown]
# A basic way to open and read a text file.
#
# * `with` begins a loop (so the file closes no matter what)
# * `r` tells the operating system you want permission to read it.
# * `.read()` tells Python to import all the text

# %% [markdown]
# Let's take a look at `negative_file` by slicing it up.

# %%
negative_file[:50]
# Out:
# 'abandoned\nabandonment\naberration\naberration\nabhorr'

# %% [markdown]
# `\n` is an End of Line character
#
# `[:50]` took the first 50 characters

# %%
negative_list = negative_file.split('\n')

# %%
negative_list[:5]
# Out:
# ['abandoned', 'abandonment', 'aberration', 'aberration', 'abhorred']

# %%
negative_list = negative_file.splitlines()

# %%
negative_list[:5]
# Out:
# ['abandoned', 'abandonment', 'aberration', 'aberration', 'abhorred']

# %% [markdown]
# ### Python starts at 0

# %%
print negative_list[0]
# Out:
# abandoned

# %%
print negative_list[0:1]
# Out:
# ['abandoned']

# %%
print negative_list[-5:]
# Out:
# ['wrought', 'yawn', 'zealot', 'zealous', 'zealously']

# %% [markdown]
# Let's do it again for the postive words

# %%
file_name = r'files/positive.txt'

with open(file_name, 'r') as infile:
    positive_file = infile.read()
    
postive_list = positive_file.splitlines()

# %%
print postive_list[-2:]
# Out:
# ['zenith', 'zest']

# %% [markdown]
# Quiz: How many words are in the two lists combined?

# %%
emotions = postive_list + negative_list
len(emotions)
# Out:
# 6136

# %%
print len(postive_list) + len(negative_list)
# Out:
# 6136

# %% [markdown]
# A while back, I use the Twitter API to get some Tweets, or status updates, that mentioned then President Obama.

# %%
obama_tweets = open('files/obama_tweets.txt', 'r').read()
obama_tweets = obama_tweets.splitlines()

# %% [markdown]
# Avoid copy and paste text in file! Define a function!

# %%
def open_list(filename):
    with open(filename, 'r') as infile:
        list_file = infile.read()
    list_file = list_file.splitlines()
    return list_file

# %%
def open_list(filename):
    '''
    Opens a text file and returns a list split by lines.
    '''
    with open(filename, 'r') as infile:
        list_file = infile.read()
    list_file = list_file.splitlines()
    return list_file

# %%
obama_tweets = open_list('files/obama_tweets.txt')

print(len(obama_tweets))
# Out:
# 1381

# %% [markdown]
# More slicing

# %%
obama_tweets[:5]
# Out:
# ['Obama has called the GOP budget social Darwinism. Nice try, but they believe in social creationism.',
#  'In his teen years, Obama has been known to use marijuana and cocaine.',
#  'IPA Congratulates President Barack Obama for Leadership Regarding JOBS Act: WASHINGTON, Apr 05, 2012 (BUSINESS W... http://t.co/8le3DC8E',
#  'RT @Professor_Why: #WhatsRomneyHiding - his connection to supporters of Critical Race Theory.... Oh wait, that was Obama, not Romney...',
#  'RT @wardollarshome: Obama has approved more targeted assassinations than any modern US prez; READ & RT: http://t.co/bfC4gbBW']

# %% [markdown]
# Some from the middle?

# %%
print obama_tweets[52:55]
# Out:
# ["Barack Obama President Ronald Reagan's Initial Actions Project: President Ronald Reagan was also facing an econo... http://t.co/8Go8oCpf", 'RT @TXGaryM: Yes #WHFail RT @jltho: This #WhatsRomneyHiding hashtag is entertaining. Is this another social media backfire from the Obama administration?', 'Barack Obama LONGBOARD Package CORE 7" TRUCKS 76mm BIGFOOT WHEELS: The newest addition to the Bigfoot Collection... http://t.co/cnHRuUBZ']

# %% [markdown]
# That's ugly.

# %%
for tweet in obama_tweets[52:55]:
    print tweet
# Out:
# Barack Obama President Ronald Reagan's Initial Actions Project: President Ronald Reagan was also facing an econo... http://t.co/8Go8oCpf
# RT @TXGaryM: Yes #WHFail RT @jltho: This #WhatsRomneyHiding hashtag is entertaining. Is this another social media backfire from the Obama administration?
# Barack Obama LONGBOARD Package CORE 7" TRUCKS 76mm BIGFOOT WHEELS: The newest addition to the Bigfoot Collection... http://t.co/cnHRuUBZ

# %% [markdown]
# Let's get going!!!

# %%
#loop, but don't go through everything yet
for tweet in obama_tweets[:5]:
    print tweet
    positive_counter = 0
    #Lower case everything
    tweet_processed = tweet.lower()
    
    #split by ' ' into a list of words
    words = tweet_processed.split()
    
    #Loop through each word in the tweet
    for word in words:
        
        clean_word = word.strip(punctuation)
        
        if clean_word in postive_list:
            print clean_word
            positive_counter = positive_counter+1
    
    print positive_counter,len(words)
# Out:
# Obama has called the GOP budget social Darwinism. Nice try, but they believe in social creationism.
# nice
# 1 16
# In his teen years, Obama has been known to use marijuana and cocaine.
# 0 13
# IPA Congratulates President Barack Obama for Leadership Regarding JOBS Act: WASHINGTON, Apr 05, 2012 (BUSINESS W... http://t.co/8le3DC8E
# 0 17
# RT @Professor_Why: #WhatsRomneyHiding - his connection to supporters of Critical Race Theory.... Oh wait, that was Obama, not Romney...
# 0 19
# RT @wardollarshome: Obama has approved more targeted assassinations than any modern US prez; READ & RT: http://t.co/bfC4gbBW
# modern
# 1 17

# %% [markdown]
# Your turn. Add a negative_counter!

# %%
#loop, but don't go through everything yet
for tweet in obama_tweets[:5]:
    print tweet
    positive_counter = 0
    #Lower case everything
    tweet_processed = tweet.lower()
    
    #split by ' ' into a list of words
    words = tweet_processed.split()
    
    #Loop through each word in the tweet
    for word in words:
        
        clean_word = word.strip(punctuation)
        
        if clean_word in postive_list:
            print clean_word
            positive_counter = positive_counter+1
    
    print positive_counter,len(words)
# Out:
# Obama has called the GOP budget social Darwinism. Nice try, but they believe in social creationism.
# nice
# 1 16
# In his teen years, Obama has been known to use marijuana and cocaine.
# 0 13
# IPA Congratulates President Barack Obama for Leadership Regarding JOBS Act: WASHINGTON, Apr 05, 2012 (BUSINESS W... http://t.co/8le3DC8E
# 0 17
# RT @Professor_Why: #WhatsRomneyHiding - his connection to supporters of Critical Race Theory.... Oh wait, that was Obama, not Romney...
# 0 19
# RT @wardollarshome: Obama has approved more targeted assassinations than any modern US prez; READ & RT: http://t.co/bfC4gbBW
# modern
# 1 17

# %%
tweet_sentiment = []

for tweet in obama_tweets[:]:


    positive_counter = 0
    negative_counter = 0
    
    #Lower case everything
    tweet_processed = tweet.lower()
    
    #split by ' ' into a list of words
    words = tweet_processed.split()
    
    #Loop through each word in the tweet
    for word in words:
        clean_word = word.strip(punctuation)
        
        if clean_word in postive_list:
            positive_counter = positive_counter + 1
        if clean_word in negative_list:
            negative_counter = negative_counter + 1
    tweet_sentiment.append([tweet,positive_counter, negative_counter, len(words)])

# %%
tweet_sentiment[:3]
# Out:
# [['Obama has called the GOP budget social Darwinism. Nice try, but they believe in social creationism.',
#   1,
#   0,
#   16],
#  ['In his teen years, Obama has been known to use marijuana and cocaine.',
#   0,
#   0,
#   13],
#  ['IPA Congratulates President Barack Obama for Leadership Regarding JOBS Act: WASHINGTON, Apr 05, 2012 (BUSINESS W... http://t.co/8le3DC8E',
#   0,
#   0,
#   17]]

# %% [markdown]
# Now let's get this out of Python

# %%
import pandas as pd

# %%
df = pd.DataFrame(tweet_sentiment,
                 columns = ['text','positive','ngative','word_count']
                 )
df.head()
# Out:
#                                                 text  positive  ngative  \
# 0  Obama has called the GOP budget social Darwini...         1        0
# 1  In his teen years, Obama has been known to use...         0        0
# 2  IPA Congratulates President Barack Obama for L...         0        0
# 3  RT @Professor_Why: #WhatsRomneyHiding - his co...         0        1
# 4  RT @wardollarshome: Obama has approved more ta...         1        1
#
#    word_count
# 0          16
# 1          13
# 2          17
# 3          19
# 4          17

# %%
df.to_csv('tweets_processed.csv')

# %% [markdown]
# Let's look at the results. If `!cat` doesn't work, try `!type` which is the Windows equivalent.

# %%
# !cat tweets_processed.csv
# Out:
# ,text,positive,ngative,word_count
# 0,"Obama has called the GOP budget social Darwinism. Nice try, but they believe in social creationism.",1,0,16
# 1,"In his teen years, Obama has been known to use marijuana and cocaine.",0,0,13
# 2,"IPA Congratulates President Barack Obama for Leadership Regarding JOBS Act: WASHINGTON, Apr 05, 2012 (BUSINESS W... http://t.co/8le3DC8E",0,0,17
# 3,"RT @Professor_Why: #WhatsRomneyHiding - his connection to supporters of Critical Race Theory.... Oh wait, that was Obama, not Romney...",0,1,19
# 4,RT @wardollarshome: Obama has approved more targeted assassinations than any modern US prez; READ & RT: http://t.co/bfC4gbBW,1,1,17
# 5,Video shows federal officials joking about cost of lavish conference http://t.co/2i4SmoPM #obama #crime #p2 #news #tcot #teaparty,1,1,17
# 6,"one Chicago kid who says ""Obama is my man"" tells Jesse Watters that the gun violence in Chicago is like ""World War 17""",0,1,23
# 7,"RT @ohgirlphrase: American kid ""You're from the UK? Ohhh cool, So do you have tea with the Queen?"". British kid: ""Do you like, go to Mcdonalds with Obama?",0,0,28
# 8,A valid explanation for why Obama won't let women on the golf course.   #WhatsRomneyHiding,1,0,14
# 9,President Obama &lt; Lindsay Lohan RUMORS beginning cross shape lights on ST &lt; 1987 Analyst64 DC bicycle courier &lt; Video changes to scramble.,0,2,23
# 10,Obama's Gender Advantage Extends to the States - 2012 Decoded: New detail on recent swing state polling further ... http://t.co/8iSanDGS,1,2,20
# 11,#WhatsRomneyHiding? Obama's dignity and sense of humor? #p2 #tcot,2,0,9
# 12,Here's How Obama and the Democrats Will Win in 2012: Let's start by going back to the assorted polls questioning... http://t.co/zpg0TVm3,1,0,21
# 13,RealClearPolitics - Obama's Organizational Advantage on Full ...: As a small but electorally significant state t... http://t.co/3Ax22aBB,2,2,17
# 14,RT @GregWHoward: Obama inherited (if you want to use his lame wording) $10.6 trillion in debt and turned it into $15.2 trillion. #tcot #p2 #ocra #teaparty,0,1,26
# 15,"RT @ohgirlphrase: American kid ""You're from the UK? Ohhh cool, So do you have tea with the Queen?"". British kid: ""Do you like, go to Mcdonalds with Obama?",0,0,28
# 16,"of course..I blame HAARP, sinners, aliens, Bush and Obama for all this.  :P....&gt;&gt; http://t.co/7eq8nebt",0,1,14
# 17,Pravda Endorses and Supports Obama   http://t.co/G68JEmkz,0,0,6
# 18,"RT @mlake9: Love how the #Obama campaign's #WhatsRomneyHiding back fired, now #WhatsObamaHiding is trending. Seeing a lot of birth certificate tweets.",1,0,21
# 19,@katie_larson It was Obama's hashtag--conservatives turned it into a game (again) :) It's funny ;),1,3,15
# 20,RT @FrankConniff: Harvard graduate Romney slammed Obama for going to Harvard. Good to know that Mitt Romney hates people like Mitt Romney.,1,0,22
# 21,RT @wilycyotee Pres. Obama's ongoing support of women is another reason I am so proud he is my President!  @edshow #Obama2012,3,0,21
# 22,"RT @ohgirlphrase: American kid ""You're from the UK? Ohhh cool, So do you have tea with the Queen?"". British kid: ""Do you like, go to Mcdonalds with Obama?",0,0,28
# 23,"RT @mlake9: Love how the #Obama campaign's #WhatsRomneyHiding back fired, now #WhatsObamaHiding is trending. Seeing a lot of birth certificate tweets.",1,0,21
# 24,RT @RandallHoven: Nixon was missing 18 minutes. Obama is missing 18 years.,0,0,12
# 25,#WhatsRomneyHiding Obama's birth certificate.,0,0,4
# 26,@edshow the direspect of President #Obama is based on racism. They do not want a Black PRESIDENT. #edshow,0,2,18
# 27,"RT @Professor_Why: #WhatsRomneyHiding - his plan to push bad loans through for Green energy just to see 'em go bankrupt... Oops, that's Obama again!",1,3,24
# 28,Thanks for the shout out in this recap of #JOBSAct signing! http://t.co/njCfZuSd via @MiamiHerald,0,0,14
# 29,"RT @haymakers: When RWers whine ""What's Obama doing about gas prices!?"" Tell them, ""Nothing. That's how the free-market works. What are you? A socialist?""",0,0,24
# 30,"RT @0ryuge: #WhatsRomneyHiding The videotape of Barack Obama sucking up to radical Rashid Khalidi. Oh wait, that's the LATimes #VetThePress #VetThePres",0,1,21
# 31,"#edshow  My President is standing up,speaking up,fighting back and I am so glad he has taken the gloves off. OBAMA 2012 @edshow",1,0,22
# 32,If Obama win 2012 Election wait til 2016 he will have full white hair! just like Bill clinton!,3,0,18
# 33,RT @Un_Progressive: .@ResistTyranny @freegalt Easy. Obama is hiding everything. Always has.,1,0,11
# 34,RT @EMcLean1982: #WhatsRomneyHiding Obama's Mom Jeans,0,0,6
# 35,Even CBS won't buy bogus WH explanation of Obama Supreme Court comments - at http://t.co/rkNdEmIy #withnewt #tpn #tcot #tlot #tpp #sgp,2,2,21
# 36,RT @Libertarian_76: I can't wait until Romney goes after Obama on NDAA. Oh wait.,0,0,14
# 37,#KimKardashiansNextBoyFriend Obama lol Michelle ain't goin 4 dat,0,0,8
# 38,Obama And The Democrats Shocked By Constitutional Restraint http://t.co/RhSzoEU7 via @IBDinvestors,1,0,11
# 39,"Obama, Romney agree: Admit women to Augusta golf club: US President Barack Obama believes women should be allowe... http://t.co/PVKrepqI",0,0,19
# 40,"RT @ohgirlphrase: American kid ""You're from the UK? Ohhh cool, So do you have tea with the Queen?"". British kid: ""Do you like, go to Mcdonalds with Obama?",0,0,28
# 41,#whatsObamahiding Kryptonite for the Grand Old Party! Obama 2012,1,0,9
# 42,RT @BunkerBlast: RT @teacherspets Obama's Budget: 'Interest Payments Will Exceed Defense Budget' in 2019  http://t.co/uddCXCjt,3,0,15
# 43,@edshow The Right has been crying about unelected judges legislation from  bench forever all of a sudden Obama says same thing he is a Thug,1,0,25
# 44,RT @Kerryepp: #WhatsRomneyHiding that he can throw a baseball like a man and not like a girl like Obama...,0,0,19
# 45,RT @Justgod007: RT @NBCNews: President Obama signs law to prohibit insider trading by members of Congress: http://t.co/sCw6mZVz,0,0,17
# 46,@JoeSixpackSays Our Troops NEED TO COME HOME !!!! BRING OUR TROOPS HOME NOW OBAMA YOU BASTARD OOOORAH SEMPER FI,0,3,19
# 47,"@BarackObama like what are you hiding, Obama?!? You are TOO MUCH!! @MittRomney",0,0,12
# 48,"@edshow If Obama is a ""thug"" and a ""bully"" then I'm not sure what to call Rush Limbaugh and Bill O.",1,1,21
# 49,"RT @ohgirlphrase: American kid ""You're from the UK? Ohhh cool, So do you have tea with the Queen?"". British kid: ""Do you like, go to Mcdonalds with Obama?",0,0,28
# 50,"Barack Obama The Pictures Generation, 1974-1984 (Metropolitan Museum of Art): This handsome book is the first co... http://t.co/TGgLdkOo",1,0,18
# 51,Barack Obama The Triumph of Caesar: A Novel of Ancient Rome [With Earbuds] (Playaway Adult Fiction): The Roman c... http://t.co/EbEYonbx,2,1,20
# 52,Barack Obama President Ronald Reagan's Initial Actions Project: President Ronald Reagan was also facing an econo... http://t.co/8Go8oCpf,0,0,17
# 53,RT @TXGaryM: Yes #WHFail RT @jltho: This #WhatsRomneyHiding hashtag is entertaining. Is this another social media backfire from the Obama administration?,1,0,21
# 54,"Barack Obama LONGBOARD Package CORE 7"" TRUCKS 76mm BIGFOOT WHEELS: The newest addition to the Bigfoot Collection... http://t.co/cnHRuUBZ",0,0,18
# 55,"Barack Obama Mir laechelt kein Fruhling, WoO 25 Sheet Music: Digital Sheet Music of Mir laechelt kein Fruhling, ... http://t.co/cuHdVHYv",0,1,20
# 56,Obama has a billion dollar war chest for his reelection.  When were through with vetting him it might as well be Monopoly $ #Resist44,2,2,24
# 57,RT @Talkmaster: Oh now I get it. Obama was talking in shorthand and we were just too dumb to understand how smart he really is.  Gagme.,2,1,26
# 58,#KimKardashiansNextBoyFriend Obama,0,0,2
# 59,These Trending Topics on #Obama and #Romney signal the start of the presidential campaign. Officially paying attention.,0,0,17
# 60,RT @HeidiForLiberty: RT @Libertarian_76: I can't wait until Romney goes after Obama on NDAA. Oh wait,0,0,16
# 61,"RT @1Directionality: ""Harry styles described Michelle Obama as a very attractive older woman"" OBAMA HIDE YOUR WIFE, STYLES IS COMING!""",1,0,20
# 62,Attorney Mario Apuzzo Files Ballot Access Challenge Against Obama Today in New Jersey http://t.co/06rD6lCL,0,2,14
# 63,RT @LiberalMel: REPUBLICANS WANT TO TAKE AWAY FREE HEALTHCARE AND SEND PUT PEOPLE IN JAIL FOR FIGHTING. REPUBLICANS ARE AHOLES!!! #DEM #OBAMA #OBAMA2012,1,0,23
# 64,"RT @Tortured_Verse: Romney has TWO Harvard degrees and he says Obama spent ""too much time at Harvard?""  http://t.co/J4bep9Q0 #p2 #tcot #wiunion #ocra #TWISTERS",0,0,23
# 65,RT @jennykassan: President Obama: for the first time ordinary Americans will be able to invest in companies they believe in #crowdfunding,2,0,21
# 66,@kellieo79 save it for michelle Obama.,0,0,6
# 67,RT @TrentOn_YouOff: Why Barack Obama trying to start stuff with our future President? Have some respect for Mitt Romney.,1,1,19
# 68,"RT @ohgirlphrase: American kid ""You're from the UK? Ohhh cool, So do you have tea with the Queen?"". British kid: ""Do you like, go to Mcdonalds with Obama?",0,0,28
# 69,#edshow Obama is passionate about healthcare - that doesn't make him a bully.,1,2,13
# 70,"Obama is a great president. He's honest, loyal, friends, smart, and wants the BEST for EVERYONE in this country, not just the rich.",7,0,23
# 71,"FSU Cultural Post: Re: Newt or Mitt VS Obama. Can either of 'em beat him?: What parts do you find distu... http://t.co/ie4ClOp9 , at RWD",0,1,25
# 72,#newbedon 4/6/2012 4:27:33 AM Obama Wins Landslide Presidential Election...With Online Gamers http://t.co/L5xqNFfD,0,0,12
# 73,"American kid ""You're from the UK? Ohhh cool, So do you have tea with the Queen?"". British kid: ""Do you like, go to Mcdonalds with Obama?",0,0,26
# 74,"RT @WhatTheFFacts: In his teen years, Obama has been known to use marijuana and cocaine.",0,0,15
# 75,The only incompetent candidate for 2012 is Obama .  Vote NoObama in 2012,0,2,13
# 76,"RT @ohgirlphrase: American kid ""You're from the UK? Ohhh cool, So do you have tea with the Queen?"". British kid: ""Do you like, go to Mcdonalds with Obama?",0,0,28
# 77,"RT @ohgirlphrase: American kid ""You're from the UK? Ohhh cool, So do you have tea with the Queen?"". British kid: ""Do you like, go to Mcdonalds with Obama?",0,0,28
# 78,"@billmaher Mr Maher I just seen the HBO documentary hot coffee.I feel so upset, we need four more years of President Obama 1000% certtain!",2,2,24
# 79,RT @RealNichelle: I love that even most that don't agree with Pres Obama's politics could appreciate that he's a Trekker. That's what IDIC is all about.,2,0,26
# 80,"RT @djtechchicago: Apparently, he's hiding Barack Obama's copy of the Constitution. #WhatsRomneyHiding",0,0,12
# 81,"RT @ohgirlphrase: American kid ""You're from the UK? Ohhh cool, So do you have tea with the Queen?"". British kid: ""Do you like, go to Mcdonalds with Obama?",0,0,28
# 82,Media Matters & Obama WH In Secret Meetings 2 Create Enemies List http://t.co/UlXo9kp3 #GOP #TCOT #TPP #Patriots #Teaparty #twisters #p2 #RS,0,2,21
# 83,"Is #Syria Obama's trump card, or will civil nukes offer result in more futile sanctions on #Iran? http://t.co/7W5qni2S",2,1,18
# 84,RT @markknoller: Obama Campaign says Romney should make public 23 years of tax returns so Americans can assess any conflicts of interest.,1,0,22
# 85,"Obama says 2012 will be a ""fun debate"": President Barack Obama says the 2012 election will be a ""fun debate"" ove... http://t.co/OGi7SdUq",4,0,22
# 86,"RT @ChicoDelainky: Mitt Romney attacked President Obama for going to Harvard, yet, Romney spent 4 years at Harvard. What's wrong with this man?!",0,1,23
# 87,"RT @ohgirlphrase: American kid ""You're from the UK? Ohhh cool, So do you have tea with the Queen?"". British kid: ""Do you like, go to Mcdonalds with Obama?",0,0,28
# 88,RT @Fake_Dispatch: I think we are all in agreement that Rick Santorum could beat Obama... at bowling.,1,0,17
# 89,"RT @ohgirlphrase: American kid ""You're from the UK? Ohhh cool, So do you have tea with the Queen?"". British kid: ""Do you like, go to Mcdonalds with Obama?",0,0,28
# 90,"Obama has called the GOP budget social Darwinism. Nice try, but they believe in social creationism.",1,0,16
# 91,"In his teen years, Obama has been known to use marijuana and cocaine.",0,0,13
# 92,"RT @edshow: Righties call Pres. Obama a ""thug"" and ""bully"" for comments on health care law hearings. Comment on FB or tweet so we can share on #edshow!",0,1,28
# 93,"RT @markknoller: AT a campaign fundraiser tonight, Pres. Obama again denounced Mitt Romney by name for his support of the House-passed GOP Budget.",1,0,23
# 94,"RT @RobertoManzana: Obama Is Like The Worst President Ever ,",0,2,10
# 95,RT @JennyErikson: Obama's college transcripts. #WhatsRomneyHiding,0,0,6
# 96,"RT @ohgirlphrase: American kid ""You're from the UK? Ohhh cool, So do you have tea with the Queen?"". British kid: ""Do you like, go to Mcdonalds with Obama?",0,0,28
# 97,"RT @ohgirlphrase: American kid ""You're from the UK? Ohhh cool, So do you have tea with the Queen?"". British kid: ""Do you like, go to Mcdonalds with Obama?",0,0,28
# 98,vote for President Barack Obama and let's keep moving forward.@BarackObama,1,0,10
# 99,Obama has approved more targeted assassinations than any modern US prez; READ & RT: http://t.co/bfC4gbBW,1,1,15
# 100,RT @GottaLaff: RT @markknoller: Pres Obama says it'll be a big debate and a fun debate because - he says - he has the truth on his side.,1,2,28
# 101,"RT @ohgirlphrase: American kid ""You're from the UK? Ohhh cool, So do you have tea with the Queen?"". British kid: ""Do you like, go to Mcdonalds with Obama?",0,0,28
# 102,"RT @DrewMcKissick: Dapper Dan, and a comb.  And a thick oppo research file on Obama. #WhatsRomneyHiding",0,0,16
# 103,"@sgaut the Architects of the housing debacle were Schumer, Fwank, Dodd and Obama who forced banks to loan trillions to the poor. #edshow",0,2,23
# 104,"RT @ohgirlphrase: American kid ""You're from the UK? Ohhh cool, So do you have tea with the Queen?"". British kid: ""Do you like, go to Mcdonalds with Obama?",0,0,28
# 105,HE DIDN'T MEAN WHAT HE SAID! Obama's Constitutional law professor spins for him b/c he's a mind reader http://t.co/GTmqufBo #tcot #tlot,0,1,21
# 106,"RT @ohgirlphrase: American kid ""You're from the UK? Ohhh cool, So do you have tea with the Queen?"". British kid: ""Do you like, go to Mcdonalds with Obama?",0,0,28
# 107,@gretawire @WhineNot This is the most transparent Obama has been since he was caught on an open mike with the Russian president.,1,0,22
# 108,"RT @ohgirlphrase: American kid ""You're from the UK? Ohhh cool, So do you have tea with the Queen?"". British kid: ""Do you like, go to Mcdonalds with Obama?",0,0,28
# 109,RT @JeffersonObama: Arianna Huffington blasting President Obama at any chance and praising GOP. This pic explains things. http://t.co/Ov6I5CoS,1,0,18
# 110,Obama signs bill to boost business startups http://t.co/zq6zC4ZO,1,0,8
# 111,"RT @wcptersn: If Obama were white, he'd be Mitt Romney.",1,0,10
# 112,"RT @HarryFacts1D: ''Harry Styles describe a Michelle Obama como una mujer muy atractiva.'' OBAMA ESCONDE A TU ESPOSA Y A TUS HIJOS, STYLES VIENE EN CAMINO.",0,0,26
# 113,"@Fake_Dispatch no way, obama would school his ass! santorum has weak arms! lmao",0,1,13
# 114,Impossible! RT @Fake_Dispatch: I think we are all in agreement that Rick Santorum could beat Obama... at bowling.,1,1,18
# 115,'Back Off' : McConnell Warns Obama Crossed 'Dangerous line'--Times  247 http://t.co/dFTjxuKB,0,2,11
# 116,I can't wait until Romney goes after Obama on NDAA. Oh wait.,0,0,12
# 117,"RT @GottaLaff: RT @markknoller: Pres Obama sayd ""I cannot wait"" for the ""big important debate"" we are going to have on these issues.",1,0,23
# 118,"RT @ohgirlphrase: American kid ""You're from the UK? Ohhh cool, So do you have tea with the Queen?"". British kid: ""Do you like, go to Mcdonalds with Obama?",0,0,28
# 119,@AC360  President Obama is a Constitutional Law scholar - give him credit and the respect that he deserves.  @JaySekulow is annoying.,1,2,21
# 120,"RT @MusicandFaith: Judicial Watch: $500,000 of Your Money to Send Michelle to Africa http://t.co/DmMaGbBz via @Po_st",0,0,16
# 121,RT @PeteXU: Obama wants Romney to release his tax return that will show an effective tax rate of under 15% and how little US citizens understand taxes.,2,1,27
# 122,"RT @JeffersonObama: 62% of U.S. Jews would reelect Obama, 4% say Israel is most important issue - Haaretz http://t.co/VhURDtdO http://t.co/gIGmn5kE",1,1,20
# 123,"RT @debv219: #edshow Whenever Obama tells the truth about the Gop, they boo hoo hoo and call him a bully.",0,1,20
# 124,#Obama is trying to strong arm Sheriff Joe to force him to drop investigation into Obama's fake birth certificate. #GOP #tcot #teaparty,1,2,22
# 125,RT @Fake_Dispatch: I think we are all in agreement that Rick Santorum could beat Obama... at bowling.,1,0,17
# 126,@WhiteHouse @BarackObama Shell sued over massive oil spills in Nigeria. President Obama: #SaveTheArctic from Shell! http://t.co/WI0ajzJX,0,0,16
# 127,"RT @ohgirlphrase: American kid ""You're from the UK? Ohhh cool, So do you have tea with the Queen?"". British kid: ""Do you like, go to Mcdonalds with Obama?",0,0,28
# 128,"A ""legislator"" who'd never passed legislation. A ""law professor"" who'd never published a law review article ... Is Obama fictional? #hhrs",0,2,21
# 129,Obama and Cantor are all smiles as JOBS Act is signed into law http://t.co/5ac6zmY0 via @zite,0,0,16
# 130,@EileenLeft @Wary12 This is from @DavidShuster IMPORTANT MSM helpRomney get away with his lies.We must warn ind voters  http://t.co/Au49TLVs,1,0,19
# 131,"RT @ohgirlphrase: American kid ""You're from the UK? Ohhh cool, So do you have tea with the Queen?"". British kid: ""Do you like, go to Mcdonalds with Obama?",0,0,28
# 132,"If Obama is a ""law professor,"" I am a Navy SEAL.  What a farce!  A Harvard law grad doesn't know Marbury v. Madison?  He's an ignorant twit.",0,2,27
# 133,"Obama says 2012 will be a ""fun debate"": President Barack Obama says the 2012 election will be a ""fun debate"" ove... http://t.co/RpPh3u0V",4,0,22
# 134,Oh well 4 more years under Obama if that's good or bad idk. But I don't think americans are stupid enough to vote for Romney.,2,2,25
# 135,RT @markknoller: Pres Obama says it'll be a big debate and a fun debate because - he says - he has the truth on his side.,1,2,26
# 136,"Talking about gas. Asked who is to blame. Tell him I can't narrow it to a single person. ""First guy all week that didnt blame Obama!""",0,3,26
# 137,"RT @ohgirlphrase: American kid ""You're from the UK? Ohhh cool, So do you have tea with the Queen?"". British kid: ""Do you like, go to Mcdonalds with Obama?",0,0,28
# 138,Obama believes women should be admitted to Augusta http://t.co/ltBrqsgc via @edshow,0,0,11
# 139,So let me get this right the supreme court is going over Obama's Healthcare reviewing and deciding whether or not to challenge it.,2,1,23
# 140,RT @JeffersonObama: Arianna Huffington blasting President Obama at any chance and praising GOP. This pic explains things. http://t.co/Ov6I5CoS,1,0,18
# 141,Holder to 5th Circuit. Obama didn't say what he said. Read letter at http://t.co/rkNdEmIy #tcot #tlot #withnewt #prolife #sgp #lnyhbt #tpp,0,0,21
# 142,"RT @thinkprogress: Romney, who has two Harvard degrees, blasts Obama for spending ""too much time at Harvard."" http://t.co/avbgNT57 #icymi",0,0,19
# 143,"RT @ohgirlphrase: American kid ""You're from the UK? Ohhh cool, So do you have tea with the Queen?"". British kid: ""Do you like, go to Mcdonalds with Obama?",0,0,28
# 144,"RT @HuffPostPol: Jim DeMint calls President Obama a ""bully"" http://t.co/2kXhMwKY",0,1,10
# 145,"RT @Fer_SmilerJB: En el backstage de los KCA's, Harry le pregunto a Michelle Obama como hacia para ordenar pizza desde la Casa Blanca.",0,0,23
# 146,RT@pslweb Endorsement Of Democrats: A Misuse Of Union Time And Money http://t.co/l3QGcWds #union #ilwu #seiu #aflcio #demproxy #union #alba,1,0,19
# 147,Obama's Signing Of JOBS Act Likely Won't Dim #GOP Charge He's Anti-Jobs http://t.co/4INNVGfC You think? #FoxNews #TeaParty #tcot #p2,0,1,19
# 148,"Obama talking about women being able to golf, while @MittRomney  cares about women making ends meet and putting food on the table!",1,0,22
# 149,"RT @ohgirlphrase: American kid ""You're from the UK? Ohhh cool, So do you have tea with the Queen?"". British kid: ""Do you like, go to Mcdonalds with Obama?",0,0,28
# 150,"RT @ohgirlphrase: American kid ""You're from the UK? Ohhh cool, So do you have tea with the Queen?"". British kid: ""Do you like, go to Mcdonalds with Obama?",0,0,28
# 151,RT @JoiningForces: Photo of the Day: First Lady Michelle Obama greets a #WoundedWarrior @ Walter Reed in #Bethesda: http://t.co/IwG56RDK,0,1,19
# 152,"RT @ohgirlphrase: American kid ""You're from the UK? Ohhh cool, So do you have tea with the Queen?"". British kid: ""Do you like, go to Mcdonalds with Obama?",0,0,28
# 153,@YungdashK I think you come across quite up yourself to think people have to earn a follow from you. You're not Barack Obama sweet cheeks,1,0,25
# 154,"RT @ohgirlphrase: American kid ""You're from the UK? Ohhh cool, So do you have tea with the Queen?"". British kid: ""Do you like, go to Mcdonalds with Obama?",0,0,28
# 155,Breaking News: Million Men March to #Jerusalem was conceived and orchestrated by #Obama's #Globalist controllers -- http://t.co/R80dwTeD,0,1,17
# 156,"RT @ohgirlphrase: American kid ""You're from the UK? Ohhh cool, So do you have tea with the Queen?"". British kid: ""Do you like, go to Mcdonalds with Obama?",0,0,28
# 157,#Obama 12' win &gt; Debt increased by 87 percent & will top $20 trillion in 2016,2,1,16
# 158,http://t.co/3COJeZ2F  STOP IT!!!,0,0,3
# 159,"RT @markknoller: AT a campaign fundraiser tonight, Pres. Obama again denounced Mitt Romney by name for his support of the House-passed GOP Budget.",1,0,23
# 160,"RT @dqnickle: I wonder who'd win in a footrace, Barack Obama or Mitt Romney...stereotypes tell me Bam...but those things aren't very reliable are they",1,0,24
# 161,RIGHT SPEAK: LET US NOT FORGET THAT PETTY SANTORUM ENDORSES OBAMA OVER ROMNEY! NOT PRESIDENTIAL! http://t.co/ZqAuGKOd #elections2012 #gop,1,1,18
# 162,Obama inherited (if you want to use his lame wording) $10.6 trillion in debt and turned it into $15.2 trillion. #tcot #p2 #ocra #teaparty,0,1,24
# 163,"RT @thinkprogress: Romney, who has two Harvard degrees, blasts Obama for spending ""too much time at Harvard."" http://t.co/avbgNT57 #icymi",0,0,19
# 164,"RT @ohgirlphrase: American kid ""You're from the UK? Ohhh cool, So do you have tea with the Queen?"". British kid: ""Do you like, go to Mcdonalds with Obama?",0,0,28
# 165,"Obamacare passed by 7 votes. For #Obama this is a ""strong majority"". LOL!  http://t.co/tX5Rx9tC #tcot #dem",1,0,16
# 166,RT @BuckSexton: interesting to see how Obama and co. game housing market to avoid final correction b4 election. millions of homes glutting market = GOP win,1,2,26
# 167,"RT @ohgirlphrase: American kid ""You're from the UK? Ohhh cool, So do you have tea with the Queen?"". British kid: ""Do you like, go to Mcdonalds with Obama?",0,0,28
# 168,RT @Talkmaster: Oh now I get it. Obama was talking in shorthand and we were just too dumb to understand how smart he really is.  Gagme.,2,1,26
# 169,"@WilliamShatner  I just seen the HBO documentary hot coffee.I feel so upset, we need four more years of President Obama 1000% certtain!!!",2,2,22
# 170,"@IamDonCheadle In your view,do you believe Obama has been an economic disaster?",0,1,12
# 171,Obama 's hair whole gray!,0,0,5
# 172,"RT @ohgirlphrase: American kid ""You're from the UK? Ohhh cool, So do you have tea with the Queen?"". British kid: ""Do you like, go to Mcdonalds with Obama?",0,0,28
# 173,#WhatsRomneyHiding HE WONDERING.. WHATS OBAMA HIDING?????  remember the most transparent adm in history.. LMBO,0,0,14
# 174,Sipsey Street Irregulars: Katie Pavlich writes an audio book. #FastandFurious: Barack Obama's Bloodiest Scandal http://t.co/x5vw6vy4,0,1,15
# 175,"En el backstage de los KCA's, Harry le pregunto a Michelle Obama como hacia para ordenar pizza desde la Casa Blanca.",0,0,21
# 176,"RT @ohgirlphrase: American kid ""You're from the UK? Ohhh cool, So do you have tea with the Queen?"". British kid: ""Do you like, go to Mcdonalds with Obama?",0,0,28
# 177,"LaFollette ""we will go to newly elected president Obama and ask for our train back""",1,0,15
# 178,"RT @HuffPostPol: Jim DeMint calls President Obama a ""bully"" http://t.co/5xHkGMDg / Soooo out of touch.",0,2,15
# 179,RT @MikeLotito15: Alright President Obama needs to pass a law that prohibits anyone and everyone from tweeting about this one direction crap. It will stop now,1,0,26
# 180,RT @BandDirFundRais: Is this the same golf course that refused to admit blacks until Tiger Woods? #WomenOnlyCourse #obama #agusta #golf http://t.co/d2tf13n0,0,0,21
# 181,"RT @ohgirlphrase: American kid ""You're from the UK? Ohhh cool, So do you have tea with the Queen?"". British kid: ""Do you like, go to Mcdonalds with Obama?",0,0,28
# 182,"@Wozniak1: @edshow Irony is fun: Obama is much friendlier with Muslim Brotherhood than the GOP, but says only later is waging war on women.",1,2,24
# 183,"Obama has called the GOP budget social Darwinism. Nice try, but they believe in social creationism.",1,0,16
# 184,"In his teen years, Obama has been known to use marijuana and cocaine.",0,0,13
# 185,"RT @Gabby_Hoffman: We want a president with a spine, not a president with fecklessness. America can do better than Obama. #resist44 #tcot RT if you agree!",1,0,26
# 186,"RT @ohgirlphrase: American kid ""You're from the UK? Ohhh cool, So do you have tea with the Queen?"". British kid: ""Do you like, go to Mcdonalds with Obama?",0,0,28
# 187,RT @JeffersonObama: Arianna Huffington blasting President Obama at any chance and praising GOP. This pic explains things. http://t.co/Ov6I5CoS,1,0,18
# 188,"RT @ohgirlphrase: American kid ""You're from the UK? Ohhh cool, So do you have tea with the Queen?"". British kid: ""Do you like, go to Mcdonalds with Obama?",0,0,28
# 189,Obama Birth Certificate http://t.co/1yZOM5d9,0,0,4
# 190,RT @Zulu_xo: #KimKardashiansNextBoyFriend Obama?,0,0,4
# 191,En el backstage de los KCA's Harry le pregunto a Michelle Obama como hacia para ordenar pizza desde la Casa Blanca #1Dfact,0,0,22
# 192,"@edshow: Pres. Obama a ""thug"" and ""bully"" well I'm glad he has my back figthing for healthcare for all! #edshow!",2,1,20
# 193,"RT @derekahunter: I like how Obama asks ""#WhatsRomneyHiding?"" My guess, Obama's crappy college transcripts. #WhatsObamaSmoking? #Caring #p2 @Messina2012",0,0,18
# 194,"RT @markknoller: Pres Obama sayd ""I cannot wait"" for the ""big important debate"" we are going to have on these issues.",1,0,21
# 195,NBC Accuses Federal Judge of Bringing Politics Into Courtroom By Questioning Obama | Media Research Center http://t.co/m3LFBhGY,0,2,17
# 196,No one thinks Obama sold out today? I do. This was a complete sell out.,0,0,15
# 197,"@BarackObama i want your real birth certificate obama,And your real college transcripts. Too bad they dont exist! barry the exchange student",2,1,21
# 198,@2happi2bsad Why not obama?,0,0,4
# 199,How Saul Alinsky Taught Obama to Say One Thing and Do the Opposite http://t.co/yg8Wl99P,0,0,14
# 200,What Obama could learn from Muhammad Ali | Stephen M. Walt: http://t.co/T8Mfzi0i,0,1,12
# 201,"@LongLiveShah the time that Obama decide 2 move his ass about mullahs,they'll nuke the whole world&still Obama wants 2 shake hands with them",0,0,23
# 202,"RT @ohgirlphrase: American kid ""You're from the UK? Ohhh cool, So do you have tea with the Queen?"". British kid: ""Do you like, go to Mcdonalds with Obama?",0,0,28
# 203,"RT @ohgirlphrase: American kid ""You're from the UK? Ohhh cool, So do you have tea with the Queen?"". British kid: ""Do you like, go to Mcdonalds with Obama?",0,0,28
# 204,"RT @JanOnAmerica: With all the truth that has been exposed about the Obama Administration, you have to wonder why any Americans in... http://t.co/1Pso0ULz",0,1,23
# 205,Mitt Romney's tweets all have something to do with Obama! Like really its not that serious,0,1,16
# 206,Obama's Budget: 'Interest Payments Will Exceed Defense Budget' in 2019 http://t.co/dKy7CI8M,3,0,11
# 207,"""@edu_castillo: Obama aboga por el ingreso de las mujeres al club de golf de Augusta// mish interesante...",0,0,17
# 208,"RT @MooseOfReason: With a range of opinion from Obama to Romney. MT @markknoller: Pres Obama says ""I cannot wait"" for ""big important debate"" on issues.",1,0,25
# 209,swear i just saw barack obama walking down my street...highly doubtful hahaha #INeedGlasses,1,3,13
# 210,RT @against_obama: Obama's illegal alien uncle's drivers license #whatsromneyhiding,0,1,9
# 211,@LeslieMarshall You mean savings...when SCOTUS tells the world that Obama is wrong.ACA is unconstitutional! Are you sure Obama is a lawyer?,1,2,21
# 212,Obama 2 versions of his ties 2 #ACORN : At 2008 debate http://t.co/2eaXDiOD - To ACORN: http://t.co/IP2xu3cW #WhatsRomneyHiding #gen44 #tcot,0,2,20
# 213,"""@SubwayEATTFRESH: WHO HASN'T KIM K DATED??? OBAMA""",0,0,7
# 214,"#WhatsRomneyHiding - his connection to supporters of Critical Race Theory.... Oh wait, that was Obama, not Romney...",0,1,17
# 215,@Solameanie Truly & O'Reilly's milquetoast  interview w/that Obama a$$ kisser &socialist (also a race baiter) Marc Lamont Hill was sickening,1,2,20
# 216,Obama campaign wants to train army of women http://t.co/48O3o6jd,0,0,9
# 217,I think we are all in agreement that Rick Santorum could beat Obama... at bowling.,1,0,15
# 218,"Oh, how fun! Another #Obama-created Hashtag #WhatsRomneyHiding Via @anthropocon",1,0,9
# 219,RT @lilcode45: why does everyone hate on obama?&lt; Cause he aint done shit for us.,0,0,15
# 220,@Harry_Styles Barack obama should hide his kids and hide his wife,0,0,11
# 221,RT @katiehiggins_x: My favourite drawing I've ever received on draw something is Nicole's drawing of Obama. Piece of art that was.,0,0,21
# 222,"@edshow President Obama made the federal court look ridiculous, and showed the RW who they truly are.",1,1,17
# 223,"RT @thinkprogress: Romney, who has two Harvard degrees, blasts Obama for spending ""too much time at Harvard."" http://t.co/avbgNT57 #icymi",0,0,19
# 224,Romney and Obama agree that Augusta National should allow women to be members? Unthinkable...and bad news for the green coats.,0,1,20
# 225,"#WhatsRomneyHiding The videotape of Barack Obama sucking up to radical Rashid Khalidi. Oh wait, that's the LATimes #VetThePress #VetThePres",0,1,19
# 226,Interesting take: Obama Misquotes Bible on Wealth Redistribution http://t.co/qGDbGxfg,1,0,9
# 227,RT @JennyErikson: Obama's college transcripts. #WhatsRomneyHiding,0,0,6
# 228,Top News Headlines: Obama Signs JOBS Act http://t.co/fCuFtbWm #business #video,1,0,10
# 229,"RT @ohgirlphrase: American kid ""You're from the UK? Ohhh cool, So do you have tea with the Queen?"". British kid: ""Do you like, go to Mcdonalds with Obama?",0,0,28
# 230,Obama seeks to defuse healthcare row with court @ http://t.co/KkaKZGHv...,0,1,10
# 231,"RT @BelleInABow: Obama doesn't need to be your favorite person, but he's still the President of the United States of America. That always deserves respect.",2,1,25
# 232,RT @LouTommoBum: Michelle Obama invited the boys to her Easter party. l0l,0,0,12
# 233,@AP 0 because i know the global elite have set up america to fail in the coming years and there doing it through there puppet obama,1,1,26
# 234,Interesting take: Obama Misquotes Bible on Wealth Redistribution http://t.co/Z2BCceVk,1,0,9
# 235,@marclamonthill Why aren't you and Obama and others telling kids to stop dressing like thugs in jail.... go to school...don't emulate thugs,0,0,22
# 236,"Look For Obama To Approve Keystone Pipeline - Right Before The Election, http://t.co/rVWI6S1Y, #TCOT",1,1,14
# 237,RT @robints: Obama Admin cries for tax increases as they applaud China 4 lowering taxes to spur econ grwth. http://t.co/iR2DAMfM Can't make it up! #tcot,0,0,25
# 238,Barack Obama is coming to FAU on Tuesday! :D,0,0,9
# 239,"RT @GEsfandiari: ""Obama signaled US would accept Iranian civilian nuclear program if Khamenei back up claim #Iran will not pursue nukes"" http://t.co/svxFPoHq",1,0,22
# 240,RT @handrewschwartz: Ignatius reports Obama signaled Iran US wld accept civ nuke pgm if Khameni can assure Iran will never get nuke weapons http://t.co/KkaAhGPq,1,0,24
# 241,#whatsromneyhiding from obama,0,0,3
# 242,"@HesDanTheMan @edshow nothing will come of it.  Had it been #obama, the #gop would impeach him. #p2 #edshow",1,0,18
# 243,Exposing the Obama-Soetoro deception: http://t.co/PFmSWQsU via @AddThis,0,1,7
# 244,OBAMA Follows The Quran &gt; Muslims can Lie to the Infidel (US) to Get achieve His Goals&gt; Destruction of the West&gt; #tcot #p2 #ocra #dem #tlot,0,3,26
# 245,"RT @blakehounshell: From Ignatius: ""U.S. officials hope [Putin] can broker a Syria deal before he meets Obama at the G-8 summit next month.""",2,0,23
# 246,RT @CatoInstitute: NEW Podcast:  Obama's Vanished Coalition http://t.co/w0cUHRM5  (h/t @COBrown),0,0,10
# 247,"American kid ""You're from the UK? Ohhh cool, So do you have tea with the Queen?"". British kid: ""Do you like, go to Mcdonalds with Obama?",0,0,26
# 248,@c_o_l_l_e_e_n Obama is ill prepared for the sh*t storm if the Catholics shut down the hospitals and universities,1,2,18
# 249,Beloit (WI) Daily News:  Obama setting up Supreme Court as a campaign issue . More #Obama #news - http://t.co/WYKgE3LZ,1,2,19
# 250,@markknoller @obama denounces @mittromney for supporting a budget? Why doesn't @obama denounce the senate for ignoring HIS budget ?,0,1,19
# 251,"RT @JonahNRO: But he got them fast! MT @thinkprogress Romney, who has two Harvard degrees, blasts Obama for spending ""too much time at Harvard.""",0,0,24
# 252,"I'll survive if America elects Obama again. After all, thats what we're all about. Electing some moron who's kiling everything we believe in",0,0,23
# 253,RT @markknoller: Pres Obama says it'll be a big debate and a fun debate because - he says - he has the truth on his side.,1,2,26
# 254,"RT @HeraMing: While #Progressives shout #WarOnWomen at #Republicans, Barack Hussein #Obama hosts Muslim ""Sharia Law"" Brotherhood AT WHITEHOUSE!! WTH?!?!",0,0,19
# 255,#WhatsRomneyHiding the secret handshake. Obama is really mad he wants to know this handshake,0,1,14
# 256,I'd like to read #Obama's #college thesis to find out if he espouses any constitutional conflicts of interest. #tcot #whatsobamahiding #p2,1,0,21
# 257,@mmfa Like the questions the liberal media gives Obama.,1,0,9
# 258,"RT @Creationtips: Ouch! Obama at prayer breakfast: Jesus Is ""A Son of God"". (CNS) | http://t.co/9a1deeP0",0,1,16
# 259,"RT @ohgirlphrase: American kid ""You're from the UK? Ohhh cool, So do you have tea with the Queen?"". British kid: ""Do you like, go to Mcdonalds with Obama?",0,0,28
# 260,RT @SteveDeaceShow: Tonight's show: the Texas Republican Party may be the last line of defense between the Constitution and another four years of Obama.,1,0,24
# 261,"RT @ohgirlphrase: American kid ""You're from the UK? Ohhh cool, So do you have tea with the Queen?"". British kid: ""Do you like, go to Mcdonalds with Obama?",0,0,28
# 262,President Obama Signs the Jumpstart Our Business Startups (JOBS) Act: An Attempt to Ease Access to Capital and... http://t.co/B2cYIX23,1,0,19
# 263,"#edshow Whenever Obama tells the truth about the Gop, they boo hoo hoo and call him a bully.",0,1,18
# 264,"RT @GEsfandiari: ""Obama signaled US would accept Iranian civilian nuclear program if Khamenei back up claim #Iran will not pursue nukes"" http://t.co/svxFPoHq",1,0,22
# 265,"RT @ohgirlphrase: American kid ""You're from the UK? Ohhh cool, So do you have tea with the Queen?"". British kid: ""Do you like, go to Mcdonalds with Obama?",0,0,28
# 266,"RT @nprnews Assailing 'Disobedience,' Pope Says Women Will Not Be Ordained http://t.co/sYSnUwUJ Compare to Obama's statement on lady golfers",1,1,19
# 267,#whatsromneyhiding the fact that he is a student of critical race theory? Or is that Obama.....?,0,0,16
# 268,"RT @GEsfandiari: ""Obama signaled US would accept Iranian civilian nuclear program if Khamenei back up claim #Iran will not pursue nukes"" http://t.co/svxFPoHq",1,0,22
# 269,Obama Attacks Justices & Now Must Answer in Court http://t.co/NKCZ0YqD. How anyone can support such a manipulative President?,1,2,18
# 270,"RT @PresElections: The Barack Obama, Mitt Romney budget battle - Ben White http://t.co/gb87afx1 via @newspin",1,1,15
# 271,"Obama has called the GOP budget social Darwinism. Nice try, but they believe in social creationism.",1,0,16
# 272,"In his teen years, Obama has been known to use marijuana and cocaine.",0,0,13
# 273,"RT @GEsfandiari: ""Obama signaled US would accept Iranian civilian nuclear program if Khamenei back up claim #Iran will not pursue nukes"" http://t.co/svxFPoHq",1,0,22
# 274,"Van Jones Echoes '08 Hillary Clinton: President Obama, 'A Great... http://t.co/B3b4vkeX",1,0,11
# 275,"RT @RealClearScott: NH is emblematic of Obama's swing state organization advantage. Already over 30 staffers, 7 offices: http://t.co/X8fkVleu",1,0,18
# 276,"Jim DeMint calls President Obama a ""bully"" http://t.co/2kXhMwKY",0,1,8
# 277,Obama Could Face Election-Year Jam on Gay Marriage| http://t.co/aViCL1rV |,0,2,10
# 278,SouthFloridaGayNews.| |#lgbt #p2 #glbt #ssm #queer #gay|,0,1,7
# 279,"With a range of opinion from Obama to Romney. MT @markknoller: Pres Obama says ""I cannot wait"" for ""big important debate"" on issues.",1,0,23
# 280,"RT @WhatTheFFacts: In his teen years, Obama has been known to use marijuana and cocaine.",0,0,15
# 281,"RT @markknoller: Pres Obama sayd ""I cannot wait"" for the ""big important debate"" we are going to have on these issues.",1,0,21
# 282,Obama's Weak-Kneed Regulatory Regime | Common Dreams: http://t.co/IZXRte2e via @AddThis,1,1,10
# 283,"RT @ohgirlphrase: American kid ""You're from the UK? Ohhh cool, So do you have tea with the Queen?"". British kid: ""Do you like, go to Mcdonalds with Obama?",0,0,28
# 284,Interesting take: Obama Misquotes Bible on Wealth Redistribution http://t.co/ejpjWjHg,1,0,9
# 285,RT lmfao @_Ciroc_Obama: Wonder if @PRINCE_POLO know Rihanna in that new movie battleship who am I kidding of course his groupie ass knew lol,0,0,24
# 286,Interesting take: Obama Misquotes Bible on Wealth Redistribution http://t.co/FNPrvVDK,1,0,9
# 287,#KimKardashiansNextBoyFriend Obama?,0,0,2
# 288,Obey: Obama still not satisfied with the lapdog press (@times247)  http://t.co/FVcoWj7p,0,0,11
# 289,Obama says knock you out -- http://t.co/PUZRq7HU #screwytees,0,2,8
# 290,RT @HonestConservat: EXCLUSIVE Selma Bouvier w 3 am Kagan 2 Obama call http://t.co/JdrQZSJr THE SHREW @SgtTim911,1,1,16
# 291,"RT @djtechchicago: Apparently, he's hiding Barack Obama's copy of the Constitution. #WhatsRomneyHiding",0,0,12
# 292,#WhatsRomneyHiding Michelle Obama's divorce attorney on speed dial?,0,1,8
# 293,Obama is a puppet for America. There's more to his face and words.,0,1,13
# 294,RT @JeffersonObama: Arianna Huffington blasting President Obama at any chance and praising GOP. This pic explains things. http://t.co/Ov6I5CoS,1,0,18
# 295,RT @charlesdavis84: All those people with Obama logos on their avatar? If someone could do that for me but with the Pepsi logo I'd appreciate it.,0,0,26
# 296,@edshow #edshow Obama is the one looking out for women the GOP is in fiction world,0,1,16
# 297,GOP calls Pres. Obama a Thug and we wonder why #TrayvonMartin / was killed,0,1,14
# 298,@BaisdenLive Look at the Barack Obama Chicken Nugget on ebay. You are not going to believe this. Why is this allowed?,0,0,21
# 299,"RT @Professor_Why: #WhatsRomneyHiding - his willingness to tell police officers they ""acted stupidly"" w/out knowing the facts... Oh wait, that's Obama again!",1,2,22
# 300,RT @markknoller: Pres Obama says it'll be a big debate and a fun debate because - he says - he has the truth on his side.,1,2,26
# 301,White House in damage control over Obama Supreme Court remarks: The White House was forced on the defensive on W... http://t.co/2Yy8Srct,3,2,21
# 302,"RT @ForAmerica: McCaskill Calls For Obama to Release Day&Half Supply of Oil From SPR via @MOPNS But Biden says oil policy is ""best it's ever been"" #MOsen",0,0,27
# 303,a  large number of #GOP women will vote for #Obama #edshow,2,0,11
# 304,Obama on the offensive! RT @BarackObama: So what's Romney hiding? Tweet @MittRomney to demand he release his tax returns. #WhatsRomneyHiding,0,1,20
# 305,Obama's college transcripts. #WhatsRomneyHiding,0,0,4
# 306,"RT @ohgirlphrase: American kid ""You're from the UK? Ohhh cool, So do you have tea with the Queen?"". British kid: ""Do you like, go to Mcdonalds with Obama?",0,0,28
# 307,"You want others to know how you feel and say sorry without you telling them what's wrong. Last time I checked, Obama is still president :/",0,3,26
# 308,RT @astroterf: RT @scarlett_0hara: RT @rightchange2012: Veteran groups blast Obama's plan 2 double (cont) http://t.co/ZuKdTidE,0,0,15
# 309,"@maddow Rachel I just seen the HBO documentary hot coffee.I feel so upset, we need four more years of President Obama 1000% certtain!",2,2,23
# 310,"American kid ""You're from the UK? Ohhh cool, So do you have tea with the Queen?"". British kid: ""Do you like, go to Mcdonalds with Obama?",0,0,26
# 311,"Obama Is Like The Worst President Ever ,",0,2,8
# 312,"RT @yahoo_music: Madonna Tweets Britney, Katy, Skrillex And Obama, Plus Exclusive Ultra Music Fest Video! http://t.co/EteMGqKk",2,0,16
# 313,"RT @keder: His record includes making businesses profitable, instead of bankrupting and extorting them. (Unlike Obama) #WhatsRomneyHiding",1,0,17
# 314,One Direction Tolak Undangan Michelle Obama! http://t.co/S8lPX0SZ [Like it? http://t.co/WIDZGjRj ],0,1,11
# 315,whats up with the obama trend ? Leave the man alone ! Hes done ALOT,0,2,15
# 316,President Obama is coming to FAU April 10 &gt;__&lt; parking is going to be worse than it already is... @nicholle_,0,1,20
# 317,My favourite drawing I've ever received on draw something is Nicole's drawing of Obama. Piece of art that was.,0,0,19
# 318,"RT @GEsfandiari: ""Obama signaled US would accept Iranian civilian nuclear program if Khamenei back up claim #Iran will not pursue nuk...",1,0,21
# 319,How come Barack Obama has twitter? Some illuminati trying to disguise himself. He puts voodoo on his followers,1,1,18
# 320,"RT @ohgirlphrase: American kid ""You're from the UK? Ohhh cool, So do you have tea with the Queen?"". British kid: ""Do you like, go to Mcdonalds with Obama?",0,0,28
# 321,"RT @17bbomb: @geoff9cow Right! Of course! It's ALWAYS someone else's fault when it comes to Obama! / about 95% is. very good odds, too.",2,1,24
# 322,"RT @ridiamond: WORD!! ""Obama's Organizational Advantage on Full Display in N.H.""",1,0,11
# 323,http://t.co/JrUSKBu9,0,0,1
# 324,Obama Signs Rare Bipartisan Jobs Bill: http://t.co/W761OyXD via @youtube,0,0,9
# 325,"RT @ohgirlphrase: American kid ""You're from the UK? Ohhh cool, So do you have tea with the Queen?"". British kid: ""Do you like, go to Mcdonalds with Obama?",0,0,28
# 326,"RT @markknoller: Pres Obama sayd ""I cannot wait"" for the ""big important debate"" we are going to have on these issues.",1,0,21
# 327,"RT @ohgirlphrase: American kid ""You're from the UK? Ohhh cool, So do you have tea with the Queen?"". British kid: ""Do you like, go to Mcdonalds with Obama?",0,0,28
# 328,"RT @ohgirlphrase: American kid ""You're from the UK? Ohhh cool, So do you have tea with the Queen?"". British kid: ""Do you like, go to Mcdonalds with Obama?",0,0,28
# 329,RT @Drudge_Report: Obama setting up Supreme Court as campaign issue... http://t.co/1IiLN01H,1,0,11
# 330,@markknoller funny Obama saying Romney should release stuff. Mr birth certificate. mr no college records. must think we are stupid.,1,1,20
# 331,RT @markknoller: Pres Obama says it'll be a big debate and a fun debate because - he says - he has the truth on his side.,1,2,26
# 332,"RT @mediaite: The Five's Greg Gutfeld: President Obama Isn't A Bully, He's A Whiner (VIDEO) http://t.co/kWBO2rSs",0,1,16
# 333,President  Obama has the highest office in America yet he hasn't the power to speak freely. So much for the First Amendment! #backoffdummies,0,0,23
# 334,Obey: Obama still not satisfied with the lapdog press http://t.co/4vxMWaZv #wethepeople in the way! #tcot #sgp,0,0,16
# 335,"RT @MsRock4Ever: GOP is SO desperate and so Frightened of President Obama that they are suppressing votes in several states, but it will cause them loss too.",1,2,27
# 336,"RT @ohgirlphrase: American kid ""You're from the UK? Ohhh cool, So do you have tea with the Queen?"". British kid: ""Do you like, go to Mcdonalds with Obama?",0,0,28
# 337,"RT @TPO_Hisself: For the first time in history, CONTRARY 2 Dr. King's wishes, Obama is calling on voters FOR THE COLOR OF THEIR SKIN! #RACIST! #TREASON!",1,3,26
# 338,Today's Federal Debt is about $15.2 Trillion. Obama has added 43% since he usurped the office of POTUS. #tcot #p2 #ocra #teaparty,0,0,22
# 339,"RT @TPO_Hisself: For the first time in history, CONTRARY 2 Dr. King's wishes, Obama is calling on voters FOR THE COLOR OF THEIR SKIN! #RACIST! #TREASON!",1,3,26
# 340,RT @Talkmaster: Oh now I get it. Obama was talking in shorthand and we were just too dumb to understand how smart he really is.  Gagme.,2,1,26
# 341,"RT @susie_c: Latest on #NDAA lawsuit from @sparrowmedia, which has the prettiest website. http://t.co/RQQpZJHd",0,0,14
# 342,"RT @ohgirlphrase: American kid ""You're from the UK? Ohhh cool, So do you have tea with the Queen?"". British kid: ""Do you like, go to Mcdonalds with Obama?",0,0,28
# 343,Still hoping that #Obama is gonna make some #Romney/Bob Ewell comparison before the night is over. http://t.co/0TBmBaKB #p2,0,0,18
# 344,RT @LouTommoBum: Michelle Obama invited the boys to her Easter party. l0l,0,0,12
# 345,RT @PoliticalGal11: Archbishop Dolan: Obama lied to his face. Read at http://t.co/wX1RzFKm #tcot #prolife #tlot #sgp #MSM #tpp #Catholic #lnyhbt #withnewt #army,0,0,22
# 346,"RT @ohgirlphrase: American kid ""You're from the UK? Ohhh cool, So do you have tea with the Queen?"". British kid: ""Do you like, go to Mcdonalds with Obama?",0,0,28
# 347,"After Threatening Judges, GOP Accuses Obama of Judicial Intimidation http://t.co/rHr93J15 via @dailykos -- #Republican #Disinformation",0,4,15
# 348,click obama related trending topic. racist bullshit every few tweets. [arrested development dove macro],0,1,14
# 349,RT @ItsLoopzProd: LOOOOOOOOOOOOOOOOOOOOOOOOOOOOL This is why i rate obama http://t.co/vsOYFhSa,0,0,10
# 350,"RT @HarryFacts1D: ''Harry Styles describe a Michelle Obama como una mujer muy atractiva.'' OBAMA ESCONDE A TU ESPOSA Y A TUS HIJOS, STYLES VIENE EN CAMINO.",0,0,26
# 351,Late Night Jokes: Obama Unqualified to Be a Trekkie: ,0,1,9
# 352,The Tonight Show With Jay Leno,0,0,6
# 353,Congratulations to Mitt Ro... http://t.co/krM3IuSt,1,0,5
# 354,RT @jltho: This #WhatsRomneyHiding hashtag is entertaining. Is this another social media backfire from the Obama administration?,1,0,17
# 355,"Obama: ""To avoid voter fraud, I have authorized $1.5B to hire the Black Panthers for Security at polling places. We are watchigng you""",1,2,23
# 356,RT @Blondiecakess: Obama's skin color is not a reason to vote for him..,1,0,13
# 357,"RT @Our4thEstate: @edshow The President of the United States, Barack Obama, is all that stands between the rights of the 99% & the Party of Koch & Norquist.",1,2,28
# 358,RT @JeffersonObama: Arianna Huffington blasting President Obama at any chance and praising GOP. This pic explains things. http://t.co/Ov6I5CoS,1,0,18
# 359,#newbedon 4/6/2012 4:25:20 AM Obama Wins Landslide Presidential Election...With Online Gamers http://t.co/JGbJwE9Z,0,0,12
# 360,"Happy Passover, love Obama http://t.co/gHQ3NrWP",2,0,5
# 361,"Obama has called the GOP budget social Darwinism. Nice try, but they believe in social creationism.",1,0,16
# 362,"In his teen years, Obama has been known to use marijuana and cocaine.",0,0,13
# 363,Why Did Obama Invite Al Sharpton to Easter Prayer Breakfast But Not Southern Baptist Leaders? http://t.co/Zgsh2zyo via @theblaze,0,0,18
# 364,"RT @ohgirlphrase: American kid ""You're from the UK? Ohhh cool, So do you have tea with the Queen?"". British kid: ""Do you like, go to Mcdonalds with Obama?",0,0,28
# 365,"RT @jmimac351: @EWErickson $4 gas, high unemployment & Obama is worried about Augusta National. This is smoke and mirrors for utter failure. #cantwait2vote",0,4,23
# ...
# 1243,"To Obama, legal precedents are all about politics http://t.co/R0LJqx8X",0,0,9
# 1244,Obama to celebrate Passover with Seder http://t.co/tIS5Umhh,0,0,7
# 1245,"RT @LauraFlyMe: ""Barry Soetoro a.k.a. Barack Obama Exposed Finally: http://t.co/Hl52R0AN via @youtube",0,1,12
# 1246,Barack Obama Traditional Mahjong http://t.co/C67LiSDV,1,0,5
# 1247,The Vetting: Obama Exploited Catholics To Push Universal Health Care In Illinois  http://t.co/NqjjCWMB,1,0,13
# 1248,RT @TCOTvideos: Obama's snafu over Supreme Court's job duties give hint as to why he has locked all his college transcripts in Fort Knox. #TCOT,1,0,25
# 1249,"RT @angel__network: Obama to sign Jobs Act into law Thursday, which is designed to make crowdfunding a legal ... http://t.co/mpTGvRvw",0,1,20
# 1250,Kal liked what Obama had to say at political rally and signed up to volunteer for campaign.,0,0,17
# 1251,"RT @MiltShook: If #202-599-9212 appears on your caller ID, it's a pro-GOP telemarketer trashing Obama. Don't answer, or answer while flushing toilet.",0,0,22
# 1252,"RT @WhatTheFFacts: In his teen years, Obama has been known to use marijuana and cocaine.",0,0,15
# 1253,RT @rickjnewman Which presidential candidate is out of touch? How about both. http://t.co/02AQUGPl #Obama #Romney,0,0,15
# 1254,RT @nat_riverascott: @Mirandacan you are so right about that #shameonyou #Obama,1,0,11
# 1255,Examiner Editorial: Obama joins attacks on court even before health care ruling | Washington Examiner http://t.co/zHkcmmyb via @addthis,1,1,18
# 1256,"#WhatsRomneyHiding That time he told AIPAC Jerusalem should remain united, then backtracked in a TV interview. No, wait. That was Obama.",0,0,21
# 1257,Is President #Obama trying to muscle the Supreme Court? @JeffreyToobin & @JaySekulow are standing by to discuss...and disagree! #AC360,1,2,19
# 1258,RT @Talkmaster: Oh now I get it. Obama was talking in shorthand and we were just too dumb to understand how smart he really is.  Gagme.,2,1,26
# 1259,Sharing: http://t.co/AEp80p7F Feds refuse to release obummer's draft docs to Sheriff Joe.,0,1,12
# 1260,The Maverick Conservative: President Obama: Hispanics/Latinos as Illegal Immigrants and Murderers http://t.co/BX2ogeQN via @addthis,0,2,14
# 1261,Is anyone else growing tired of the Obama Administration's relentless class warfare tactics? They're maddening and un-American.,0,4,17
# 1262,RT @anna12061: Another Obama Buddy!,0,0,5
# 1263,http://t.co/B2WIWFrV,0,0,1
# 1264,,0,0,0
# 1265,"Napolitano Caught Hiring Muslim Brotherhood Terrorist, Giving Him Top-Secret Security Clearance",1,0,11
# 1266,"RT @whitehouse: Today President Obama signed the #JOBSAct - encourages startups, supports #smallbiz: http://t.co/YyeRYmHT",0,1,14
# 1267,@MJ_Obama you right though enjoy your self my nigg we gon he wilding soon,1,0,14
# 1268,It's a sorry state of affairs when the US President menaces other branches of government. Obama mocks and menaces like governing is sport.,0,1,23
# 1269,"American kid ""You're from the UK? Ohhh cool, So do you have tea with the Queen?"". British kid: ""Do you like, go to Mcdonalds with Obama?",0,0,26
# 1270,"@PAC43 wonder if Obama's buddies will lose their passports too? Buffet,Geither& Immelt?",1,0,12
# 1271,Obama aboga por el ingreso de las mujeres al club de golf de Augusta http://t.co/zhKx6rQE,0,0,15
# 1272,"With Obama's budget, interest payments on the debt will exceed our entire defense budget in 2019.. #tcot  http://t.co/tmsSKR0T",3,0,18
# 1273,"""@Ciroc_Obama: #IBLOCKA""",0,0,2
# 1274,"#Obama and #Romney agree on including #women at the Augusta Golf Club &gt; Well, waiting for #Mitt to #FlipFlop any minute now :-) #weasel",1,1,24
# 1275,LOL RT @esqcapades #WhatsRomneyHiding The secret code that would let Obama be clear.,0,0,13
# 1276,how come Justin Bieber has more followers than Barack Obama,0,0,10
# 1277,"RT @BelleInABow: Obama doesn't need to be your favorite person, but he's still the President of the United States of America. That always deserves respect.",2,1,25
# 1278,"#WhatsRomneyHiding - his long-form birth certificate for 2 1/2 years... Oh wait, that little game was played by Obama, not Romney...",0,3,21
# 1279,@edshow It's great. Obama is looking out for women.,1,0,9
# 1280,Penn is changing the conversation from his film career to his involvement with the Obama administration.,0,0,16
# 1281,"In Obama's Budget, Interest Payments on the Debt Will Exceed Defense in 2019. http://t.co/ta0Gs2Su #twcot #tlot #tcot",3,0,17
# 1282,RT @Talkmaster: Oh now I get it. Obama was talking in shorthand and we were just too dumb to understand how smart he really is.  Gagme.,2,1,26
# 1283,"RT @SayfieReview: Herald: ""Jewbags"" flap exposes rift in Barack Obama-Debbie Wasserman Schultz World http://t.co/7jswRZAQ #sayfie",0,1,15
# 1284,http://t.co/nl8vX5Of,0,0,1
# 1285,#WhatsRomneyHiding - we all know Romney can't Eff with President Obama!,0,1,11
# 1286,I hope @PitchyPete uses this list to assign seats at his future dinner party. I want to talk fave TMNT w/ Obama & Oprah http://t.co/RoLLLTt2,1,1,25
# 1287,@ATeagirl The Obama propaganda department came out with that hashtag regarding Romney's tax records.,0,1,14
# 1288,"RT @thinkprogress: Romney, who has two Harvard degrees, blasts Obama for spending ""too much time at Harvard."" http://t.co/avbgNT57 #icymi",0,0,19
# 1289,Obey: Obama still not satisfied with the lapdog press (@times247) http://t.co/qSQXWxnl Now he's 'ordering' what the press should report!,0,0,19
# 1290,"Obama has called the GOP budget social Darwinism. Nice try, but they believe in social creationism.",1,0,16
# 1291,"In his teen years, Obama has been known to use marijuana and cocaine.",0,0,13
# 1292,RT @Talkmaster: Oh now I get it. Obama was talking in shorthand and we were just too dumb to understand how smart he really is.  Gagme.,2,1,26
# 1293,"#WhatsRomneyHiding Obama's birth cert,smh dis guy ix really funny,lol",0,0,9
# 1294,GOP senator accuses Obama of threatening the Supreme Court - The Hill's Blog Briefing Room http://t.co/gVSs6ulN,1,3,16
# 1295,#WhatsRomneyHiding Obama's college transcripts?,0,0,4
# 1296,"RT @paulrevered1776: RT @Professor_Why: #WhatsRomneyHiding - the fact that he was very close to a domestic terrorist- Oh wait, that's Obama",0,2,21
# 1297,Is Despot better? @workinmama @RednaxalA Calling Obama a despot gives him more respectability than his sort is due; a thug. #obama2012 #gop,1,2,22
# 1298,#Google #Hot #News Comments by Obama set off imbroglio http://t.co/mbVzVzKt #InstantFollowBack YBNews,1,1,12
# 1299,RT @anna12061: Another Obama Buddy!,0,0,5
# 1300,http://t.co/B2WIWFrV,0,0,1
# 1301,,0,0,0
# 1302,"Napolitano Caught Hiring Muslim Brotherhood Terrorist, Giving Him Top-Secret Security Clearance",1,0,11
# 1303,"@JeffersonObama it would look like the president is doing good. Goes against their narrative ""everything sucks Obama fault No one likes him""",1,1,22
# 1304,Is Obama 'Dangerously Close To Totalitarianism'?,0,1,6
# 1305, http://t.co/KeC3MhTg,0,0,1
# 1306,"FINALLY - A former Obama law student speaks out -- and he can't believe the crap spewing from O's mouth, either: http://t.co/GLopiyOC",0,2,22
# 1307,Reforming an Obama supporter is like trying to pick up poop by its clean end,2,1,15
# 1308,LOOOOOOOOOOOOOOOOOOOOOOOOOOOOL This is why i rate obama http://t.co/vsOYFhSa,0,0,8
# 1309,"RT @larryeldershow: Spike Lee said he dislikes black-white couples, gives them ""visual daggers"". Yo, Spike, if you got your way, Obama wouldn't exist.",0,0,23
# 1310,"[121] In March 2009, Obama reversed a Bush-era policy which had limited funding of embryonic stem cell research",0,1,18
# 1311,"RT @DrewMTips: #WhatsRomneyHiding His association with convicted felon Tony Rezko and domestic terrorist Bill Ayers. Wait, that's Obama.",0,1,18
# 1312,I just signed a petition asking Pres. Obama to fulfill the promise of National Alzheimer's Project Act at: http://t.co/WEbFZPlb,2,0,19
# 1313,"I heard there is a gay porn titled ""Obama Been Slobbin"" ....now think about who Obama killed in Pakistan..yeah crazy",0,1,20
# 1314,Sanctioning Iran to Influence Israel,0,0,5
# 1315,"If President Obama is concerned that his efforts at ""diplomacy"" with Iran... http://t.co/nrVeFQPQ",0,0,13
# 1316,#WhatsRomneyHiding The secret code that would let Obama be clear.,0,0,10
# 1317,"How do you spell FAILURE - ""OBAMA""",0,2,7
# 1318,#tcot #sgp #teaparty,0,0,3
# 1319,@WAMK I was implying that you think Obama is not as smart as the Supreme Court. Apologies for the misunderstanding.,2,1,20
# 1320,"#WhatsRomneyHiding His demand that Israel retreat to indefensible borders from which she can be destroyed. No, wait. That's Obama.",0,2,19
# 1321,@Mar_Pizzle miles away from u.lol.. obama town,0,0,7
# 1322,RT @terresamonroe: Obama Is Making the Case For His Own Impeachment http://t.co/hbWWnakJ,0,0,12
# 1323,RT @ArkansasBoys: #IWantToPunchPeopleWho voted for Obama #arkansasboyproblems,0,0,7
# 1324,"As Obama's policies have turned women into 3rd class citizens, he is working on bringing down the whole economy. #edshow",0,1,20
# 1325,#WhatsObamaHiding RT @conkc2: #WhatsRomneyHiding A cheeseburger from Michelle. &lt;-----That's Obama again. He keeps it in his coat pocket.,0,0,18
# 1326,@iChicagoScott hahaha left of Obama. That's great,1,0,7
# 1327,"Despite rising gas prices, energy policy experts Charles Ebinger & Susan Tierney say you can't blame Obama on #TheTavisSmileyShow this week.",0,3,21
# 1328,quisiera ser la hija de Obama. ah porque (?),0,1,9
# 1329,RT @RT_America Obama's pretzel logic http://t.co/Shv83Z0F @PeterSchiff #Obama campaign,0,0,9
# 1330,FEAR IS THE MINDKILLER. OH NO ITS OBAMA..MUMMMYYYYYYYYYY!!!!!!!!! http://t.co/p2vrYRFz,0,1,9
# 1331,Obama's Signing Of JOBS Act Likely Won't Dim GOP C...:  President Obama's signing of the JOBS Act gives him one ... http://t.co/pWArEGsR,0,2,22
# 1332,@Gabby_Hoffman Community Organizers in one zip code in Chicago could do better than Obama.,1,0,14
# 1333,"RT @CBSSports: Obama, Romney say admit women to Augusta golf club - http://t.co/OtHTaRDK",0,1,13
# 1334,#WhatsRomneyHiding The fact that he can beat Obama!,0,0,8
# 1335,RT @markknoller: Obama Campaign says Romney should make public 23 years of tax returns so Americans can assess any conflicts of interest.,1,0,22
# 1336,@edshow I'M A WOMAN NOT A CATERPILLAR.  OBAMA IN 2012 #ED SHOW,0,0,12
# 1337,"Amid Trayvon Martin case, Obama hosts screening of 'To Kill a Mockingbird' - http://t.co/vvaTNwON http://t.co/MzerPkAh",0,1,15
# 1338,Top Secret Obama 2012 World War 3 Illuminati Antichrist Conspiracy!: http://t.co/iqg1xarL via @youtube,2,2,13
# 1339,"Obama Respects the Supreme Court Says Eric Holder, Violence in Syria Continues in Anticipation of... http://t.co/4PEbWUGs #libertario #tlot",1,0,18
# 1340,#WhatsRomneyHiding? That he has a lot of money. OH WAIT ANYONE WITH A BRAIN ALREADY KNEW THAT. Dumbest hashtag ever. Obama has money too FYI,0,0,25
# 1341,#WhatsRomneyHiding ?  less than how much Obama's hiding from the public.  That's what.,0,2,13
# 1342,"Obama Respects the Supreme Court Says Eric Holder, Violence in Syria Continues in Anticipation of... http://t.co/TUqvEApu #libertario #tlot",1,0,18
# 1343,RT @edshow: Women at Augusta? Obama says absolutely. Romney hedges. Comment on FB or tweet so we can share on #edshow!,0,0,21
# 1344,"Obama Respects the Supreme Court Says Eric Holder, Violence in Syria Continues in Anticipation of... http://t.co/5QBOVrBw #libertario #tlot",1,0,18
# 1345,"RT @Professor_Why: #WhatsRomneyHiding - his lack of knowledge regarding Constitutional Checks & Balances... Oh wait, that's our Constitutional ""scholar"" Obama!",0,3,20
# 1346,"Obama Respects the Supreme Court Says Eric Holder, Violence in Syria Continues in Anticipation of... http://t.co/Duemei61 #libertario #tlot",1,0,18
# 1347,"Obama Respects the Supreme Court Says Eric Holder, Violence in Syria Continues in Anticipation of... http://t.co/S4UHjSVS #libertario #tlot",1,0,18
# 1348,"Obama Respects the Supreme Court Says Eric Holder, Violence in Syria Continues in Anticipation of... http://t.co/DHvGqb1Z #libertario #tlot",1,0,18
# 1349,"Obama Respects the Supreme Court Says Eric Holder, Violence in Syria Continues in Anticipation of... http://t.co/8Mp8Bg3y #libertario #tlot",1,0,18
# 1350,"RT @thinkprogress: Romney, who has two Harvard degrees, blasts Obama for spending ""too much time at Harvard."" http://t.co/avbgNT57",0,0,18
# 1351,Middle-class professionals only losers in Coalition government's tax changes - Telegrap http://t.co/ONvpI8jR you in USA HOLD OBAMA ON YR  SH,0,1,20
# 1352,"Obama Respects the Supreme Court Says Eric Holder, Violence in Syria Continues in Anticipation of... http://t.co/QJYdOvLj #libertario #tlot",1,0,18
# 1353,RT @stonerjesus420: Six National Drug Policy Organizations Send Letter Asking Obama To End MMJ Crackdown: http://t.co/fFZKYkLF,0,1,16
# 1354,RT @poorconservativ: Obama Is Trying To Bully The Supreme Court With His Warning About Health Care Law  http://t.co/aKzIOEDM,1,3,18
# 1355,@obama start tweeting dang,0,0,4
# 1356,"Holder answers judge, defending both judiciary and Obama health care remarks http://t.co/EAS8WNVU",0,0,12
# 1357,@Androushka The liberals have seen to it that parents can have no choice in schools and may not send their children to schools like Obama's,0,0,25
# 1358,RT @Ausflatfish #Obama Administration indicts 6th #whistleblower under the #Espionage Act http://t.co/xYdHGtKJ #media #journalism,0,0,14
# 1359,"73% of Democrats said Bush could lower gas prices, but now only 33% think #Obama can. Graph: http://t.co/d2X461u2 @yaliberty",0,0,19
# 1360,"I bet Obama didn't think about calculus when he promised change. Yeah, we will bring change, but will we calculate the change? Damn home ...",2,2,25
# 1361,@John_37058 How long do you think it will take Obama to write an executive order giving him the right to use it on us?,2,0,24
# 1362,"RT @ohgirlphrase: American kid ""You're from the UK? Ohhh cool, So do you have tea with the Queen?"". British kid: ""Do you like, go to Mcdonalds with Obama?",0,0,28
# 1363,"Is Obama a dumb nigger, or what?!?!  Holder Says Court Power To Review Laws 'beyond Dispute' | Fox News http://t.co/yhJ55xhM via @addthis",0,3,22
# 1364,You niggas are fake that's word to Obama - Lil B,0,2,11
# 1365,"RT @GranholmTWR: Tonight @MikeAllen gives us the inside scoop on the election. Also, Obama's fmr. advisor Austan Goolsbee will talk jobs & the economy.",1,1,24
# 1366,The hundreds of millions of dollars in taxes Obama donor Warren Buffett owes to the federal government. #WhatsRomneyHiding,0,0,18
# 1367,OKAY. HOW ON THE EARTH DID BARACK OBAMA PUT THAT BLENDER ON HIS TWITTER? I WANT TOO.,1,0,17
# 1368,"RT @ForAmerica: Obama claims #ObamaCare was passed with a ""strong majority."" How does he keep a straight face and say that? #tcot #VAsen #MOsen #FLsen",2,0,25
# 1369,RT @MrMcMillin: hahahahahaha  http://t.co/LW1S5Iea #Obama #Clinton,0,0,6
# 1370,"@BrianBrownNet: Commentary: Barack Obama Mining Trayvon's Grave -  Poor Trayvon Martin, dying... http://t.co/gk6vL04x",0,4,13
# 1371, #mainstreammedia,0,0,1
# 1372,Obama hosts screening of 'To Kill a Mockingbird' http://t.co/ylSMZBNx,0,0,9
# 1373,RT @handrewschwartz: Ignatius reports Obama signaled Iran US wld accept civ nuke pgm if Khameni can assure Iran will never get nuke weapons http://t.co/KkaAhGPq,1,0,24
# 1374,RT @edshow: Women at Augusta? Obama says absolutely. Romney hedges. Comment on FB or tweet so we can share on #edshow!,0,0,21
# 1375,@liberalminds Its trending idiot.. Did you look at the tweets? LOL they are all making fun of Obama for his stupid Hashtag,1,2,22
# 1376,RT @AstoldByBass: #KimKardashiansNextBoyfriend Barack Obama,0,0,5
# 1377,RT @GatorNation41: gas was $1.92 when Obama took office...I guess he did promise he would change things http://t.co/TlfMmi0G,1,0,18
# 1378,"@xShwag haha i know im just so smart, i mean you gotta listen to obama cuz its obama. and lol i got my belly button pierced.",2,1,26
# 1379,#OBAMA:  DICTATOR IN TRAINING.  If he passes this training course in November this country is freaking SCREWED!,0,1,17
# 1380,RT @SoCalConservtiv: His failed budget proposal that was voted down 414-0 in Congress... Oh wait that's Professor Obama #WhatsRomneyHiding #tcot,0,1,20

# %% [markdown]
# Why only 5 rows?

# %% [markdown]
# The `csv` file can be read in other programs.

# %% [markdown]
# In case your wondering, I would probably make my code a little different

# %%
def clean_split(tweet):
    ''' Take sentence and return cleaned list of words '''
    return [word.strip(punctuation) for word in tweet.lower().split()]

#turn the lists into sets so we can do intersections
postive_set  = set(postive_list)
negative_set = set(negative_list)


sentiment = []
for tweet in obama_tweets:
    words = clean_split(tweet)
    postive_counter =  len( postive_set.intersection(words) )
    negative_counter = len( negative_set.intersection(words) )
    sentiment.append ( [ postive_counter , negative_counter, len(words)] )

with  open('tweet_sentiment_2.csv','w') as csv_file:
    csv_writer = csv.writer( csv_file )
    csv_writer.writerows(sentiment)

# %% [markdown]
# #### Some takeaways
#
# 1. That's most of what you need to know in Python.
#     1. List comprehension
#     1. Functions/Classes
# 2. Start simple.
#     1.  Develop a solution for one case
#     2.  Scale up (so make sure your 2A is generalizable.)
